# %%
# %cd /home/juriostegui/work/Latent-Imagination
# Out:
# /home/juriostegui/work/Latent-Imagination

# %%
# !python run.py test models=["./runs/vae_conv/checkpoints/epoch157.ckpt"] tests=["ood"]
# Out:
# /home/juriostegui/work/env/lib/python3.11/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: '/home/juriostegui/work/env/lib/python3.11/site-packages/torchvision/image.so: undefined symbol: _ZN3c106detail23torchInternalAssertFailEPKcS2_jS2_RKSs'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(
# [✓] Evaluation complete. Summary written to /home/juriostegui/work/Latent-Imagination/tests/metrics_summary.yaml

# %%
import os
from IPython.display import display, Image

image_dir = './tests/ood'

if os.path.isdir(image_dir):
    print(f"Images found in: {image_dir}")
    for filename in os.listdir(image_dir):
        if filename.endswith(('.png', '.jpg', '.jpeg', '.gif')):
            print(f"Displaying {filename}:")
            display(Image(os.path.join(image_dir, filename)))
else:
    print(f"Error: Directory not found at {image_dir}")
# Out:
# Images found in: ./tests/ood
# Displaying epoch157_salt_pepper_timeline.png:
# Displaying ood_reconstruction_mse.png:
# Displaying epoch157_identity_timeline.png:
# Displaying epoch157_cutout_timeline.png:
# Displaying epoch157_white_noise_timeline.png:
# Displaying epoch157_gaussian_blur_timeline.png:
